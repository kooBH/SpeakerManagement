# %%
from deepface import DeepFace
import cv2
import numpy as np
import time
from tqdm import tqdm
# Out:
# 2025-11-18 11:41:41.622019: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-18 11:41:41.624025: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-18 11:41:41.664616: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-18 11:41:41.665607: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-18 11:41:42.243058: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ```
# img_path (str, np.ndarray, IO[bytes], or Sequence[Union[str, np.ndarray, IO[bytes]]]):
#             The exact path to the image, a numpy array
#             in BGR format, a file object that supports at least `.read` and is opened in binary
#             mode, or a base64 encoded image. If the source image contains multiple faces,
#             the result will include information for each detected face. If a sequence is provided,
#             each element should be a string or numpy array representing an image, and the function
#             will process images in batch.
#
#         model_name (str): Model for face recognition. Options: VGG-Face, Facenet, Facenet512,
#             OpenFace, DeepFace, DeepID, Dlib, ArcFace, SFace and GhostFaceNet
#             (default is VGG-Face.).
# ```

# %%
path_vid = "../sample/ES2002a.Closeup1.clip.mp4"
cap = cv2.VideoCapture(path_vid)
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
n_frame = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))


fourcc = cv2.VideoWriter_fourcc(*'DIVX') 
cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
prev_face = [0,0,0,0]

embeddings = []


out = cv2.VideoWriter("out.avi", fourcc, fps,(width, height) )

idx = 0
for _ in tqdm(range(n_frame)):
    ret, frame = cap.read()
    if not ret:
        break
    #print(frame.shape)
    results = DeepFace.represent(frame, enforce_detection=False,model_name ="DeepFace",detector_backend = 'yolov8')

#    print(f"-- frame {idx} --")
    for result in results:
        print(f"{result.keys()}")
#        print(f"{result['face_confidence']} | {result['facial_area']}" )
        xs = result['facial_area']['x']
        ys = result['facial_area']['y']
        xe = xs + result['facial_area']['w']
        ye = ys + result['facial_area']['h']
        cv2.rectangle(frame, (xs, ys), (xe, ye), (0, 255, 0), 2)
    embeddings.append(result)
    out.write(frame)

    idx += 1

#    if idx > 10 :
#        break
   
cap.release()
# Out:
#   0%|          | 1/1940 [00:01<39:33,  1.22s/it]
# dict_keys(['embedding', 'facial_area', 'face_confidence'])
#   0%|          | 2/1940 [00:02<38:46,  1.20s/it]
# dict_keys(['embedding', 'facial_area', 'face_confidence'])
#   0%|          | 3/1940 [00:03<38:14,  1.18s/it]
# dict_keys(['embedding', 'facial_area', 'face_confidence'])
#   0%|          | 4/1940 [00:04<38:04,  1.18s/it]
# dict_keys(['embedding', 'facial_area', 'face_confidence'])
#   0%|          | 5/1940 [00:05<38:11,  1.18s/it]
# dict_keys(['embedding', 'facial_area', 'face_confidence'])
#   0%|          | 5/1940 [00:06<42:23,  1.31s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_285229/191568164.py in ?()
#      20     ret, frame = cap.read()
#      21     if not ret:
#      22         break
#      23     #print(frame.shape)
# ---> 24     results = DeepFace.represent(frame, enforce_detection=False,model_name ="DeepFace",detector_backend = 'yolov8')
#      25
#      26 #    print(f"-- frame {idx} --")
#      27     for result in results:
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/deepface/DeepFace.py in ?(img_path, model_name, enforce_detection, detector_backend, align, expand_percentage, normalization, anti_spoofing, max_faces)
#     446
#     447         - face_confidence (float): Confidence score of face detection. If `detector_backend` is set
#     448             to 'skip', the confidence will be 0 and is nonsensical.
#     449     """
# --> 450     return representation.represent(
#     451         img_path=img_path,
#     452         model_name=model_name,
#     453         enforce_detection=enforce_detection,
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/deepface/modules/representation.py in ?(img_path, model_name, enforce_detection, detector_backend, align, expand_percentage, normalization, anti_spoofing, max_faces)
#     159     # Convert list of images to a numpy array for batch processing
#     160     batch_images = np.concatenate(batch_images, axis=0)
#     161
#     162     # Forward pass through the model for the entire batch
# --> 163     embeddings = model.forward(batch_images)
#     164
#     165     resp_objs_dict = defaultdict(list)
#     166     for idy, batch_index in enumerate(batch_indexes):
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/deepface/models/FacialRecognition.py in ?(self, img)
#      32
#      33         if img.ndim == 4 and img.shape[0] == 1:
#      34             # model.predict causes memory issue when it is called in a for loop
#      35             # embedding = model.predict(img, verbose=0)[0].tolist()
# ---> 36             embeddings = self.model(img, training=False).numpy()
#      37         elif img.ndim == 4 and img.shape[0] > 1:
#      38             embeddings = self.model.predict_on_batch(img)
#      39         else:
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/keras/utils/traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/keras/engine/training.py in ?(self, *args, **kwargs)
#     554                 super().__call__(inputs, *copied_args, **copied_kwargs)
#     555
#     556             layout_map_lib._map_subclass_model_variable(self, self._layout_map)
#     557
# --> 558         return super().__call__(*args, **kwargs)
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/keras/utils/traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/keras/engine/base_layer.py in ?(self, *args, **kwargs)
#    1141
#    1142                 with autocast_variable.enable_auto_cast_variables(
#    1143                     self._compute_dtype_object
#    1144                 ):
# -> 1145                     outputs = call_fn(inputs, *args, **kwargs)
#    1146
#    1147                 if self._activity_regularizer:
#    1148                     self._handle_activity_regularization(inputs, outputs)
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/keras/utils/traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/keras/engine/functional.py in ?(self, inputs, training, mask)
#     508         Returns:
#     509             A tensor if there is a single output, or
#     510             a list of tensors if there are more than one outputs.
#     511         """
# --> 512         return self._run_internal_graph(inputs, training=training, mask=mask)
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/keras/engine/functional.py in ?(self, inputs, training, mask)
#     665                 if any(t_id not in tensor_dict for t_id in node.flat_input_ids):
#     666                     continue  # Node is not computable, try skipping.
#     667
#     668                 args, kwargs = node.map_arguments(tensor_dict)
# --> 669                 outputs = node.layer(*args, **kwargs)
#     670
#     671                 # Update tensor_dict.
#     672                 for x_id, y in zip(
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/keras/utils/traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/keras/engine/base_layer.py in ?(self, *args, **kwargs)
#    1141
#    1142                 with autocast_variable.enable_auto_cast_variables(
#    1143                     self._compute_dtype_object
#    1144                 ):
# -> 1145                     outputs = call_fn(inputs, *args, **kwargs)
#    1146
#    1147                 if self._activity_regularizer:
#    1148                     self._handle_activity_regularization(inputs, outputs)
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/keras/utils/traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/keras/layers/locally_connected/locally_connected2d.py in ?(self, inputs)
#     334     def call(self, inputs):
#     335         if self.implementation == 1:
# --> 336             output = backend.local_conv(
#     337                 inputs,
#     338                 self.kernel,
#     339                 self.kernel_size,
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/keras/backend.py in ?(inputs, kernel, kernel_size, strides, output_shape, data_format)
#    6657
#    6658         if data_format == "channels_last":
#    6659             slices.append(slice(None))
#    6660
# -> 6661         xs.append(reshape(inputs[slices], (1, -1, feature_dim)))
#    6662
#    6663     x_aggregate = concatenate(xs, axis=0)
#    6664     output = batch_dot(x_aggregate, kernel)
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1173
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
#    1176         return dispatch_target(*args, **kwargs)
# -> 1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179         # TypeError, when given unexpected types.  So we need to catch both.
#    1180         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/tensorflow/python/ops/array_ops.py in ?(tensor, slice_spec, var)
#    1110           packed_strides = gen_math_ops.cast(packed_strides, dtypes.int16)
#    1111     else:
#    1112       var_empty = constant([], dtype=dtypes.int32)
#    1113       packed_begin = packed_end = packed_strides = var_empty
# -> 1114     return strided_slice(
#    1115         tensor,
#    1116         packed_begin,
#    1117         packed_end,
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1173
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
#    1176         return dispatch_target(*args, **kwargs)
# -> 1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179         # TypeError, when given unexpected types.  So we need to catch both.
#    1180         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/tensorflow/python/ops/array_ops.py in ?(input_, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, var, name)
#    1283
#    1284   if strides is None:
#    1285     strides = ones_like(begin)
#    1286
# -> 1287   op = gen_array_ops.strided_slice(
#    1288       input=input_,
#    1289       begin=begin,
#    1290       end=end,
#
# ~/anaconda3/envs/iitp/lib/python3.10/site-packages/tensorflow/python/ops/gen_array_ops.py in ?(input, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, name)
#   10699         "new_axis_mask", new_axis_mask, "shrink_axis_mask", shrink_axis_mask)
#   10700       return _result
#   10701     except _core._NotOkStatusException as e:
#   10702       _ops.raise_from_not_ok_status(e, name)
# > 10703     except _core._FallbackException:
#   10704       pass
#   10705     try:
#   10706       return strided_slice_eager_fallback(
#
# KeyboardInterrupt:
